# %% [markdown]
# <a href="https://colab.research.google.com/github/lisethrubio/Project4-Machine_Learning_Model/blob/Steven_branch2/Health_Prediction_Model_Class_x_12dim_inc_gender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
body_df = pd.read_csv('/bodyPerformance.csv')
body_df.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
# Encode (convert to dummy variables) the "gender" column
gender_encoded = pd.get_dummies(body_df['gender'], prefix="gender", dtype=int)

# %%
gender_encoded.head()
# Out:
#    gender_F  gender_M
# 0         0         1
# 1         0         1
# 2         0         1
# 3         0         1
# 4         0         1

# %%
# Concatenate the scaled data DataFrame with the "IMF Country Code" encoded dummies
new_body_df = pd.concat([body_df, gender_encoded], axis=1)

# %%
# Encode the target variable 'class'
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(new_body_df["class"].values)

# Remove 'class' and 'gender' columns from the features data
X = new_body_df.drop(columns=["class", "gender"]).values

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for the neural network
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes=4)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=4)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()

# Update input_dim to match the number of input features (10)
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=12))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Output layer for 4 classes with softmax activation
nn_model.add(tf.keras.layers.Dense(units=4, activation="softmax"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=155)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3621 - loss: 1.2823
# Epoch 2/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5836 - loss: 0.9367
# Epoch 3/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6147 - loss: 0.8600
# Epoch 4/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6249 - loss: 0.8315
# Epoch 5/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6418 - loss: 0.8133
# Epoch 6/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6487 - loss: 0.7959
# Epoch 7/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6590 - loss: 0.7765
# Epoch 8/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6753 - loss: 0.7571
# Epoch 9/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6795 - loss: 0.7517
# Epoch 10/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6950 - loss: 0.7268
# Epoch 11/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7099 - loss: 0.6947
# Epoch 12/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7131 - loss: 0.7077
# Epoch 13/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7148 - loss: 0.6924
# Epoch 14/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7181 - loss: 0.6968
# Epoch 15/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7313 - loss: 0.6701
# Epoch 16/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7225 - loss: 0.6671
# Epoch 17/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7265 - loss: 0.6652
# Epoch 18/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7272 - loss: 0.6605
# Epoch 19/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7295 - loss: 0.6594
# Epoch 20/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7408 - loss: 0.6407
# Epoch 21/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7354 - loss: 0.6417
# Epoch 22/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7356 - loss: 0.6447
# Epoch 23/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7288 - loss: 0.6441
# Epoch 24/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7392 - loss: 0.6355
# Epoch 25/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7375 - loss: 0.6362
# Epoch 26/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7398 - loss: 0.6364
# Epoch 27/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7350 - loss: 0.6414
# Epoch 28/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7420 - loss: 0.6269
# Epoch 29/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7346 - loss: 0.6301
# Epoch 30/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7472 - loss: 0.6115
# Epoch 31/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7516 - loss: 0.6064
# Epoch 32/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7415 - loss: 0.6227
# Epoch 33/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7509 - loss: 0.6088
# Epoch 34/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7514 - loss: 0.6170
# Epoch 35/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7410 - loss: 0.6157
# Epoch 36/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7437 - loss: 0.6191
# Epoch 37/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7481 - loss: 0.6108
# Epoch 38/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7442 - loss: 0.6140
# Epoch 39/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7306 - loss: 0.6305
# Epoch 40/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7381 - loss: 0.6277
# Epoch 41/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7540 - loss: 0.5995
# Epoch 42/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7367 - loss: 0.6306
# Epoch 43/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7467 - loss: 0.6093
# Epoch 44/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7455 - loss: 0.6074
# Epoch 45/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7441 - loss: 0.6162
# Epoch 46/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7475 - loss: 0.6123
# Epoch 47/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7476 - loss: 0.6075
# Epoch 48/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7501 - loss: 0.6038
# Epoch 49/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7439 - loss: 0.6128
# Epoch 50/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7499 - loss: 0.5977
# Epoch 51/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7518 - loss: 0.5954
# Epoch 52/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7435 - loss: 0.6186
# Epoch 53/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7580 - loss: 0.5887
# Epoch 54/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7519 - loss: 0.6013
# Epoch 55/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7446 - loss: 0.6117
# Epoch 56/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7598 - loss: 0.5852
# Epoch 57/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7537 - loss: 0.5928
# Epoch 58/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7568 - loss: 0.5905
# Epoch 59/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7531 - loss: 0.5941
# Epoch 60/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7563 - loss: 0.5913
# Epoch 61/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7481 - loss: 0.5963
# Epoch 62/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7442 - loss: 0.6117
# Epoch 63/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7529 - loss: 0.5869
# Epoch 64/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7512 - loss: 0.5985
# Epoch 65/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7538 - loss: 0.5891
# Epoch 66/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7566 - loss: 0.5926
# Epoch 67/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7484 - loss: 0.5981
# Epoch 68/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7457 - loss: 0.6096
# Epoch 69/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7507 - loss: 0.6037
# Epoch 70/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7490 - loss: 0.5984
# Epoch 71/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7457 - loss: 0.6020
# Epoch 72/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7570 - loss: 0.5991
# Epoch 73/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7554 - loss: 0.5928
# Epoch 74/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7587 - loss: 0.5935
# Epoch 75/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7602 - loss: 0.5846
# Epoch 76/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7607 - loss: 0.5927
# Epoch 77/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7514 - loss: 0.5941
# Epoch 78/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7494 - loss: 0.6061
# Epoch 79/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7538 - loss: 0.5995
# Epoch 80/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7573 - loss: 0.5908
# Epoch 81/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7601 - loss: 0.5871
# Epoch 82/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7546 - loss: 0.5874
# Epoch 83/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7557 - loss: 0.5986
# Epoch 84/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7553 - loss: 0.5953
# Epoch 85/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7582 - loss: 0.5852
# Epoch 86/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7561 - loss: 0.5919
# Epoch 87/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7514 - loss: 0.5992
# Epoch 88/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7616 - loss: 0.5839
# Epoch 89/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7537 - loss: 0.5969
# Epoch 90/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7544 - loss: 0.5895
# Epoch 91/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7545 - loss: 0.6018
# Epoch 92/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7572 - loss: 0.5803
# Epoch 93/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7565 - loss: 0.5800
# Epoch 94/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7481 - loss: 0.5996
# Epoch 95/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7574 - loss: 0.5883
# Epoch 96/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7673 - loss: 0.5870
# Epoch 97/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7617 - loss: 0.5904
# Epoch 98/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7527 - loss: 0.5936
# Epoch 99/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7503 - loss: 0.5919
# Epoch 100/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7511 - loss: 0.5937
# Epoch 101/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7523 - loss: 0.5891
# Epoch 102/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7647 - loss: 0.5791
# Epoch 103/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7583 - loss: 0.5846
# Epoch 104/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.5793
# Epoch 105/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7616 - loss: 0.5849
# Epoch 106/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7556 - loss: 0.5760
# Epoch 107/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7534 - loss: 0.5924
# Epoch 108/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7577 - loss: 0.5761
# Epoch 109/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7607 - loss: 0.5894
# Epoch 110/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7607 - loss: 0.5904
# Epoch 111/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7637 - loss: 0.5797
# Epoch 112/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7598 - loss: 0.5909
# Epoch 113/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7560 - loss: 0.5919
# Epoch 114/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7531 - loss: 0.5873
# Epoch 115/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7684 - loss: 0.5771
# Epoch 116/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7579 - loss: 0.5818
# Epoch 117/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7631 - loss: 0.5763
# Epoch 118/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7598 - loss: 0.5875
# Epoch 119/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7665 - loss: 0.5773
# Epoch 120/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7562 - loss: 0.5896
# Epoch 121/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7631 - loss: 0.5791
# Epoch 122/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7684 - loss: 0.5718
# Epoch 123/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7623 - loss: 0.5854
# Epoch 124/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7627 - loss: 0.5798
# Epoch 125/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7589 - loss: 0.5857
# Epoch 126/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7564 - loss: 0.5866
# Epoch 127/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7573 - loss: 0.5770
# Epoch 128/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7659 - loss: 0.5811
# Epoch 129/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7673 - loss: 0.5735
# Epoch 130/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7556 - loss: 0.5852
# Epoch 131/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7644 - loss: 0.5753
# Epoch 132/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7562 - loss: 0.5897
# Epoch 133/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7600 - loss: 0.5822
# Epoch 134/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7707 - loss: 0.5847
# Epoch 135/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7594 - loss: 0.5807
# Epoch 136/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7588 - loss: 0.5860
# Epoch 137/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7596 - loss: 0.5870
# Epoch 138/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7567 - loss: 0.5890
# Epoch 139/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7636 - loss: 0.5760
# Epoch 140/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7592 - loss: 0.5787
# Epoch 141/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7661 - loss: 0.5746
# Epoch 142/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7588 - loss: 0.5874
# Epoch 143/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7594 - loss: 0.5885
# Epoch 144/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7622 - loss: 0.5788
# Epoch 145/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7697 - loss: 0.5748
# Epoch 146/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7660 - loss: 0.5718
# Epoch 147/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7632 - loss: 0.5790
# Epoch 148/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7662 - loss: 0.5714
# Epoch 149/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7608 - loss: 0.5842
# Epoch 150/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7623 - loss: 0.5760
# Epoch 151/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7547 - loss: 0.5918
# Epoch 152/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7652 - loss: 0.5783
# Epoch 153/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7601 - loss: 0.5836
# Epoch 154/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7629 - loss: 0.5871
# Epoch 155/155
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7593 - loss: 0.5859

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 105/105 - 0s - 3ms/step - accuracy: 0.7537 - loss: 0.6219
# Loss: 0.6218504309654236, Accuracy: 0.7536578178405762

# %%
# Export our model to HDF5 file
from google.colab import files
nn_model.save('Health_Prediction_Model_Class_x_12dim_inc_gender.h5')
files.download('Health_Prediction_Model_Class_x_12dim_inc_gender.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
