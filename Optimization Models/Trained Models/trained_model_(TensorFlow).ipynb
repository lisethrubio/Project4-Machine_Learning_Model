# %% [markdown]
# # PART 1: DEPENDENCIES AND LOADING DATA

# %%
# Import our dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf

# %%
# Reading CSV file from the Resources folder into a pandas DataFrame

body_performance_df = pd.read_csv('/content/bodyPerformance.csv')
body_performance_df.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %% [markdown]
# # PART 2: CLEANING DATA

# %%
# Datatypes
body_performance_df.dtypes
# Out:
# age                        float64
# gender                      object
# height_cm                  float64
# weight_kg                  float64
# body fat_%                 float64
# diastolic                  float64
# systolic                   float64
# gripForce                  float64
# sit and bend forward_cm    float64
# sit-ups counts             float64
# broad jump_cm              float64
# class                       object
# dtype: object

# %%
# Unique values
body_performance_df.nunique()
# Out:
# age                          44
# gender                        2
# height_cm                   467
# weight_kg                  1398
# body fat_%                  527
# diastolic                    89
# systolic                    102
# gripForce                   550
# sit and bend forward_cm     528
# sit-ups counts               81
# broad jump_cm               245
# class                         4
# dtype: int64

# %%
# Renaming columns
body_performance_df.rename(columns={
    'age': 'Age',
    'gender': 'Gender',
    'height_cm': 'Height (cm)',
    'weight_kg': 'Weight (Kg)',
    'body fat_%': 'Body Fat %',
    'diastolic': 'Diastolic BP',
    'systolic': 'Systolic BP',
    'gripFroce': 'Grip Froce',
    'sit and bend forward_cm': 'Sit and Bend Froward (cm)',
    'sit-ups counts': 'Sit-Ups Counts',
    'broad jump_cm': 'Broad Jump (cm)',
    'class': 'Classification'
}, inplace=True)

body_performance_df.head()
# Out:
#     Age Gender  Height (cm)  Weight (Kg)  Body Fat %  Diastolic BP  \
# 0  27.0      M        172.3        75.24        21.3          80.0
# 1  25.0      M        165.0        55.80        15.7          77.0
# 2  31.0      M        179.6        78.00        20.1          92.0
# 3  32.0      M        174.5        71.10        18.4          76.0
# 4  28.0      M        173.8        67.70        17.1          70.0
#
#    Systolic BP  gripForce  Sit and Bend Froward (cm)  Sit-Ups Counts  \
# 0        130.0       54.9                       18.4            60.0
# 1        126.0       36.4                       16.3            53.0
# 2        152.0       44.8                       12.0            49.0
# 3        147.0       41.4                       15.2            53.0
# 4        127.0       43.5                       27.1            45.0
#
#    Broad Jump (cm) Classification
# 0            217.0              C
# 1            229.0              A
# 2            181.0              C
# 3            219.0              B
# 4            217.0              B

# %%
#
body_performance_df['Classification'] = body_performance_df['Classification'].replace({'B':'A', 'C':'D'})
body_performance_df.head()
# Out:
#     Age Gender  Height (cm)  Weight (Kg)  Body Fat %  Diastolic BP  \
# 0  27.0      M        172.3        75.24        21.3          80.0
# 1  25.0      M        165.0        55.80        15.7          77.0
# 2  31.0      M        179.6        78.00        20.1          92.0
# 3  32.0      M        174.5        71.10        18.4          76.0
# 4  28.0      M        173.8        67.70        17.1          70.0
#
#    Systolic BP  gripForce  Sit and Bend Froward (cm)  Sit-Ups Counts  \
# 0        130.0       54.9                       18.4            60.0
# 1        126.0       36.4                       16.3            53.0
# 2        152.0       44.8                       12.0            49.0
# 3        147.0       41.4                       15.2            53.0
# 4        127.0       43.5                       27.1            45.0
#
#    Broad Jump (cm) Classification
# 0            217.0              D
# 1            229.0              A
# 2            181.0              D
# 3            219.0              A
# 4            217.0              A

# %% [markdown]
# # PART 3" CREATE LABELS SET (y) AND FEATURES (X)

# %%
# Creating new DataFrame for transformed non-numeric data to numeric, Boolean data.

body_performance_numeric_df = pd.get_dummies(body_performance_df, columns=['Gender'], dtype=int)

# Displaying the first few rows
body_performance_numeric_df.head()
# Out:
#     Age  Height (cm)  Weight (Kg)  Body Fat %  Diastolic BP  Systolic BP  \
# 0  27.0        172.3        75.24        21.3          80.0        130.0
# 1  25.0        165.0        55.80        15.7          77.0        126.0
# 2  31.0        179.6        78.00        20.1          92.0        152.0
# 3  32.0        174.5        71.10        18.4          76.0        147.0
# 4  28.0        173.8        67.70        17.1          70.0        127.0
#
#    gripForce  Sit and Bend Froward (cm)  Sit-Ups Counts  Broad Jump (cm)  \
# 0       54.9                       18.4            60.0            217.0
# 1       36.4                       16.3            53.0            229.0
# 2       44.8                       12.0            49.0            181.0
# 3       41.4                       15.2            53.0            219.0
# 4       43.5                       27.1            45.0            217.0
#
#   Classification  Gender_F  Gender_M
# 0              D         0         1
# 1              A         0         1
# 2              D         0         1
# 3              A         0         1
# 4              A         0         1

# %%
# Initiating the LabelEncoder

le = LabelEncoder()

# Applying LabelEncoder to the classification column (the labels)

body_performance_numeric_df['Classification'] = le.fit_transform(body_performance_numeric_df['Classification'].values)

# %%
# Separating data into labels and features

y = body_performance_numeric_df['Classification']

X = body_performance_numeric_df.drop(columns=['Classification'])

# %%
# Classification column contains: A, B, C, D
# A=Great_Health B=Good_Health C=Average_Health D=Need_more_training
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Classification, dtype: int64

# %%
# value counts for label (y) data
y.value_counts()
# Out:
# Classification
# 1    6698
# 0    6695
# Name: count, dtype: int64

# %%
X.head()
# Out:
#     Age  Height (cm)  Weight (Kg)  Body Fat %  Diastolic BP  Systolic BP  \
# 0  27.0        172.3        75.24        21.3          80.0        130.0
# 1  25.0        165.0        55.80        15.7          77.0        126.0
# 2  31.0        179.6        78.00        20.1          92.0        152.0
# 3  32.0        174.5        71.10        18.4          76.0        147.0
# 4  28.0        173.8        67.70        17.1          70.0        127.0
#
#    gripForce  Sit and Bend Froward (cm)  Sit-Ups Counts  Broad Jump (cm)  \
# 0       54.9                       18.4            60.0            217.0
# 1       36.4                       16.3            53.0            229.0
# 2       44.8                       12.0            49.0            181.0
# 3       41.4                       15.2            53.0            219.0
# 4       43.5                       27.1            45.0            217.0
#
#    Gender_F  Gender_M
# 0         0         1
# 1         0         1
# 2         0         1
# 3         0         1
# 4         0         1

# %%
# value counts for features (X) data
X.value_counts()
# Out:
# Age   Height (cm)  Weight (Kg)  Body Fat %  Diastolic BP  Systolic BP  gripForce  Sit and Bend Froward (cm)  Sit-Ups Counts  Broad Jump (cm)  Gender_F  Gender_M
# 27.0  157.0        49.10        30.7        70.0          86.0         27.7       19.7                       51.0            167.0            1         0           2
# 21.0  148.0        42.00        22.8        62.0          104.0        22.4       23.8                       26.0            155.0            1         0           1
# 42.0  165.1        54.40        14.5        82.0          146.0        36.5       16.2                       47.0            211.0            0         1           1
#       162.8        60.10        27.4        82.0          129.0        28.2       19.5                       38.0            156.0            1         0           1
#       163.0        57.60        24.1        98.0          148.0        30.6       16.6                       33.0            148.0            1         0           1
#                                                                                                                                                                    ..
# 27.0  166.4        67.70        22.2        70.0          134.0        38.2       16.6                       50.0            211.0            0         1           1
#       166.5        58.50        19.7        79.0          125.0        31.4       22.0                       32.0            150.0            1         0           1
#                    71.92        37.7        78.0          133.0        28.1       26.6                       40.0            161.0            1         0           1
#       166.6        66.40        37.8        85.0          122.0        18.7       18.5                       15.0            132.0            1         0           1
# 64.0  183.5        75.40        17.2        80.0          143.0        46.5       21.0                       34.0            188.0            0         1           1
# Name: count, Length: 13392, dtype: int64

# %% [markdown]
# # PART 4: SPLIT DATA INTO TRAINING AND TESTING SETS

# %%
# Splitting data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.shape
# Out:
# (10044, 12)

# %% [markdown]
# # PART 5: FIT AND TRANSFORM DATA

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # PART 6: KERAS SEQUENTIAL MODEL CREATION

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

neural_network_model = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE

neural_network_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=12))

# Second hidden layer
#  YOUR CODE GOES HERE

neural_network_model.add(tf.keras.layers.Dense(units=30, activation="sigmoid"))

# Output layer
#  YOUR CODE GOES HERE

neural_network_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
neural_network_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 80)                  │           1,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 30)                  │           2,430 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 1)                   │              31 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,501 (13.68 KB)
#  Trainable params: 3,501 (13.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # PART 7: COMPILE KERAS SEQUENTIAL MODEL AND TRAIN DATASET

# %%
# Compile the model
#  YOUR CODE GOES HERE

neural_network_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE

fit_model = neural_network_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7404 - loss: 0.5363
# Epoch 2/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8312 - loss: 0.3738
# Epoch 3/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8456 - loss: 0.3517
# Epoch 4/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8507 - loss: 0.3365
# Epoch 5/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8644 - loss: 0.3177
# Epoch 6/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8635 - loss: 0.3142
# Epoch 7/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8742 - loss: 0.3030
# Epoch 8/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8768 - loss: 0.2937
# Epoch 9/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8701 - loss: 0.2996
# Epoch 10/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8720 - loss: 0.2961
# Epoch 11/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8650 - loss: 0.3042
# Epoch 12/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8756 - loss: 0.2858
# Epoch 13/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8748 - loss: 0.2911
# Epoch 14/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8713 - loss: 0.2922
# Epoch 15/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8723 - loss: 0.2892
# Epoch 16/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8770 - loss: 0.2824
# Epoch 17/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8718 - loss: 0.2855
# Epoch 18/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8837 - loss: 0.2727
# Epoch 19/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8747 - loss: 0.2877
# Epoch 20/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8840 - loss: 0.2758
# Epoch 21/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8808 - loss: 0.2782
# Epoch 22/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8822 - loss: 0.2725
# Epoch 23/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8796 - loss: 0.2733
# Epoch 24/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8812 - loss: 0.2804
# Epoch 25/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8798 - loss: 0.2789
# Epoch 26/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8808 - loss: 0.2714
# Epoch 27/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8812 - loss: 0.2727
# Epoch 28/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.