# %% [markdown]
# <a href="https://colab.research.google.com/github/lisethrubio/Project4-Machine_Learning_Model/blob/Steven_branch/Health_Prediction_Model_Class_x_10dim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
body_df = pd.read_csv('/content/bodyPerformance.csv')
body_df.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
# Encode the target variable 'class'
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(body_df["class"].values)

# Remove 'class' and 'gender' columns from the features data
X = body_df.drop(columns=["class", "gender"]).values

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for the neural network
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes=4)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=4)

# %%
# Define the deep learning model
nn_model = tf.keras.models.Sequential()

# Update input_dim to match the number of input features (10)
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=10))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Output layer for 4 classes with softmax activation
nn_model.add(tf.keras.layers.Dense(units=4, activation="softmax"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.3088 - loss: 1.3763
# Epoch 2/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5593 - loss: 0.9705
# Epoch 3/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5991 - loss: 0.8837
# Epoch 4/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6220 - loss: 0.8504
# Epoch 5/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6430 - loss: 0.8165
# Epoch 6/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6480 - loss: 0.8115
# Epoch 7/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6576 - loss: 0.7903
# Epoch 8/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6583 - loss: 0.7904
# Epoch 9/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6561 - loss: 0.7812
# Epoch 10/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6622 - loss: 0.7649
# Epoch 11/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6723 - loss: 0.7546
# Epoch 12/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6678 - loss: 0.7584
# Epoch 13/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6756 - loss: 0.7495
# Epoch 14/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6750 - loss: 0.7439
# Epoch 15/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6872 - loss: 0.7323
# Epoch 16/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6809 - loss: 0.7417
# Epoch 17/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6889 - loss: 0.7249
# Epoch 18/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6879 - loss: 0.7315
# Epoch 19/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6914 - loss: 0.7172
# Epoch 20/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6938 - loss: 0.7276
# Epoch 21/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6931 - loss: 0.7176
# Epoch 22/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7033 - loss: 0.7009
# Epoch 23/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7004 - loss: 0.7101
# Epoch 24/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6982 - loss: 0.7054
# Epoch 25/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6987 - loss: 0.7035
# Epoch 26/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7064 - loss: 0.7066
# Epoch 27/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7115 - loss: 0.6961
# Epoch 28/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7015 - loss: 0.7046
# Epoch 29/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7001 - loss: 0.7057
# Epoch 30/100
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.