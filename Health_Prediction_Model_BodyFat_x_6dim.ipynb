# %% [markdown]
# <a href="https://colab.research.google.com/github/lisethrubio/Project4-Machine_Learning_Model/blob/Steven_branch/Health_Prediction_Model_BodyFat_x_6dim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
body_df = pd.read_csv('/content/bodyPerformance.csv')
body_df.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
# Set 'body fat_%' as the target variable
y = body_df["body fat_%"].values

# Remove 'body fat_%', 'class', and 'gender' columns from the features data
X = body_df.drop(columns=["body fat_%", "class", "gender"]).values

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Preprocess numerical data for the neural network
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model for regression
nn_model = tf.keras.models.Sequential()

# Update input_dim to match the number of input features (9)
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=9))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Output layer for regression with linear activation
nn_model.add(tf.keras.layers.Dense(units=1, activation="linear"))

# Compile the Sequential model with a regression loss function
nn_model.compile(loss="mean_squared_error", optimizer="adam", metrics=["mean_squared_error"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 402.9197 - mean_squared_error: 402.9197
# Epoch 2/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 60.9602 - mean_squared_error: 60.9602
# Epoch 3/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 28.6006 - mean_squared_error: 28.6006
# Epoch 4/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 23.2240 - mean_squared_error: 23.2240
# Epoch 5/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 19.0314 - mean_squared_error: 19.0314
# Epoch 6/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 17.9307 - mean_squared_error: 17.9307
# Epoch 7/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16.6513 - mean_squared_error: 16.6513
# Epoch 8/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 16.3698 - mean_squared_error: 16.3698
# Epoch 9/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.4441 - mean_squared_error: 15.4441
# Epoch 10/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.3874 - mean_squared_error: 15.3874
# Epoch 11/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17.2787 - mean_squared_error: 17.2787
# Epoch 12/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15.0337 - mean_squared_error: 15.0337
# Epoch 13/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.1503 - mean_squared_error: 14.1503
# Epoch 14/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.7989 - mean_squared_error: 14.7989
# Epoch 15/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 15.7090 - mean_squared_error: 15.7090
# Epoch 16/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 15.8492 - mean_squared_error: 15.8492
# Epoch 17/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 14.6692 - mean_squared_error: 14.6692
# Epoch 18/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 14.6057 - mean_squared_error: 14.6057
# Epoch 19/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 14.1973 - mean_squared_error: 14.1973
# Epoch 20/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 13.8034 - mean_squared_error: 13.8034
# Epoch 21/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.3964 - mean_squared_error: 14.3964
# Epoch 22/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.5610 - mean_squared_error: 14.5610
# Epoch 23/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.7737 - mean_squared_error: 13.7737
# Epoch 24/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.1180 - mean_squared_error: 15.1180
# Epoch 25/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.7013 - mean_squared_error: 13.7013
# Epoch 26/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.5666 - mean_squared_error: 13.5666
# Epoch 27/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.7500 - mean_squared_error: 13.7500
# Epoch 28/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8836 - mean_squared_error: 13.8836
# Epoch 29/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.0417 - mean_squared_error: 15.0417
# Epoch 30/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6177 - mean_squared_error: 13.6177
# Epoch 31/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8291 - mean_squared_error: 13.8291
# Epoch 32/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.5260 - mean_squared_error: 13.5260
# Epoch 33/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 14.3984 - mean_squared_error: 14.3984
# Epoch 34/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 13.9844 - mean_squared_error: 13.9844
# Epoch 35/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 14.0172 - mean_squared_error: 14.0172
# Epoch 36/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9648 - mean_squared_error: 13.9648
# Epoch 37/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9853 - mean_squared_error: 13.9853
# Epoch 38/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8752 - mean_squared_error: 13.8752
# Epoch 39/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12.9473 - mean_squared_error: 12.9473
# Epoch 40/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.1138 - mean_squared_error: 14.1138
# Epoch 41/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.5963 - mean_squared_error: 13.5963
# Epoch 42/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.0571 - mean_squared_error: 14.0571
# Epoch 43/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 13.5113 - mean_squared_error: 13.5113
# Epoch 44/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.4474 - mean_squared_error: 13.4474
# Epoch 45/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.9412 - mean_squared_error: 13.9412
# Epoch 46/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.7744 - mean_squared_error: 13.7744
# Epoch 47/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 13.1968 - mean_squared_error: 13.1968
# Epoch 48/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 14.4874 - mean_squared_error: 14.4874
# Epoch 49/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.6547 - mean_squared_error: 13.6547
# Epoch 50/50
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.3678 - mean_squared_error: 13.3678

# %%
# Evaluate the model using the test data
model_loss, model_mse = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss (MSE): {model_loss}")
# Out:
# 105/105 - 0s - 2ms/step - loss: 12.9711 - mean_squared_error: 12.9711
# Loss (MSE): 12.971115112304688
